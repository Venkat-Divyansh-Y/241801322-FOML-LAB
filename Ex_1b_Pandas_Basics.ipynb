# %%
import pandas as pd
data = [10, 20, 30, 40, 50]
series = pd. Series (data)
print(series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
a = [1, 7, 2]
myvar = pd.Series (a, index =["x", "y", "z"])


print (myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
gt = series > 25
print("series>25= \n",gt)
series_filtered = series [series > 25]
print("Filtered Series: \n", series_filtered)
series_multiplied = series*2
print("\nSeries after Scalar Multiplication: \n", series_multiplied)
# Out:
# series>25=
#  0    False
# 1    False
# 2     True
# 3     True
# 4     True
# dtype: bool
# Filtered Series:
#  2    30
# 3    40
# 4    50
# dtype: int64
#
# Series after Scalar Multiplication:
#  0     20
# 1     40
# 2     60
# 3     80
# 4    100
# dtype: int64

# %%
import numpy as np
print("series= \n",series)
series_sqrt = np.sqrt(series)
print("\nSeries after Applying Square Root: \n", series_sqrt)
# Out:
# series=
#  0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
#
# Series after Applying Square Root:
#  0    3.162278
# 1    4.472136
# 2    5.477226
# 3    6.324555
# 4    7.071068
# dtype: float64

# %%
data = {
      "calories": [420, 380, 390],
          "duration": [50, 40, 45]
          }
df = pd.DataFrame(data)
print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
'year':[2000, 2001, 2002, 2001, 2002, 2003],
'pop' :[1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame = pd.DataFrame(data)
print (frame)
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame = pd.DataFrame(data, columns=['year', 'state', 'pop'])
print(frame)
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %%
frame2 = pd.DataFrame(data, columns=['year', 'state', 'pop', 'debt'], index=['one', 'two', 'three', 'four', 'five', 'six'])
print(frame2)
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Nevada  3.2  NaN

# %%
print(frame2 ['year'])
print("\n", frame2['state'])
print("\n", frame2.state)
# Out:
# one      2000
# two      2001
# three    2002
# four     2001
# five     2002
# six      2003
# Name: year, dtype: int64
#
#  one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# six      Nevada
# Name: state, dtype: object
#
#  one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# six      Nevada
# Name: state, dtype: object

# %%
print (frame2.loc['one'])
print (frame2.loc[['two', 'three']])
# Out:
# year     2000
# state    Ohio
# pop       1.5
# debt      NaN
# Name: one, dtype: object
#        year state  pop debt
# two    2001  Ohio  1.7  NaN
# three  2002  Ohio  3.6  NaN

# %%
frame2['debt'] = 12.4
print(frame2)
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5  12.4
# two    2001    Ohio  1.7  12.4
# three  2002    Ohio  3.6  12.4
# four   2001  Nevada  2.4  12.4
# five   2002  Nevada  2.9  12.4
# six    2003  Nevada  3.2  12.4

# %%
import numpy as np
frame2['debt'] = np.arange(6.)
print(frame2)
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   0.0
# two    2001    Ohio  1.7   1.0
# three  2002    Ohio  3.6   2.0
# four   2001  Nevada  2.4   3.0
# five   2002  Nevada  2.9   4.0
# six    2003  Nevada  3.2   5.0

# %%
val = pd.Series([-1.2, -1.5, -1.7], index =['two', 'four','five'])
frame2['debt']= val
print(frame2)
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7  -1.2
# three  2002    Ohio  3.6   NaN
# four   2001  Nevada  2.4  -1.5
# five   2002  Nevada  2.9  -1.7
# six    2003  Nevada  3.2   NaN

# %%
frame2['eastern'] = frame2.state == 'Ohio'
print(frame2)
# Out:
#        year   state  pop  debt  eastern
# one    2000    Ohio  1.5   NaN     True
# two    2001    Ohio  1.7  -1.2     True
# three  2002    Ohio  3.6   NaN     True
# four   2001  Nevada  2.4  -1.5    False
# five   2002  Nevada  2.9  -1.7    False
# six    2003  Nevada  3.2   NaN    False

# %%
del frame2['eastern']
print(frame2)
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7  -1.2
# three  2002    Ohio  3.6   NaN
# four   2001  Nevada  2.4  -1.5
# five   2002  Nevada  2.9  -1.7
# six    2003  Nevada  3.2   NaN

# %%
print(frame2.T)
# Out:
#         one   two three    four    five     six
# year   2000  2001  2002    2001    2002    2003
# state  Ohio  Ohio  Ohio  Nevada  Nevada  Nevada
# pop     1.5   1.7   3.6     2.4     2.9     3.2
# debt    NaN  -1.2   NaN    -1.5    -1.7     NaN

# %%
obj = pd.Series([4.5, 7.2, -5.3, 3.6], index=['d', 'b', 'a', 'c'])
print(obj)
obj2 = obj.reindex(['a', 'b', 'c', 'd', 'e'])
obj2
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# e    NaN
# dtype: float64

# %%
obj3 = pd.Series(['blue', 'purple', 'yellow'], index=[0, 2, 4])
print(obj3)
obj4 = obj3.reindex(range(6), method='ffill')
obj4
# Out:
# 0      blue
# 2    purple
# 4    yellow
# dtype: object
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object

# %%
obj3 = pd.Series(['blue', 'purple', 'yellow'], index=[0, 2, 4])
obj4 = obj3.reindex(range(6), method='ffill')
print("Method 'ffil':")
print(obj4)

obj5=obj3.reindex(range(6), method='bfill')
print("\nMethod 'bfill':")
print(obj5)

obj6 = obj3.reindex(range(6), fill_value='red')
print("\nFill value:")
print(obj6)

obj7 = pd.Series([1, 2, 3], index=[0, 2, 5])
obj8 = obj7.reindex(range(7), method='ffill',limit=1)
print("\nLimit:")
print(obj8)
# Out:
# Method 'ffil':
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object
#
# Method 'bfill':
# 0      blue
# 1    purple
# 2    purple
# 3    yellow
# 4    yellow
# 5       NaN
# dtype: object
#
# Fill value:
# 0      blue
# 1       red
# 2    purple
# 3       red
# 4    yellow
# 5       red
# dtype: object
#
# Limit:
# 0    1.0
# 1    1.0
# 2    2.0
# 3    2.0
# 4    NaN
# 5    3.0
# 6    3.0
# dtype: float64

# %%
obj = pd.Series(np.arange(5.), index=['a', 'b', 'c', 'd', 'e'])
new_obj = obj.drop('c')
print(new_obj)
obj.drop(['d', 'c'])
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# dtype: float64
# a    0.0
# b    1.0
# e    4.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                  index=['Ohio', 'Dallas', 'NJ', 'New York'],
                                    columns=['one', 'two', 'three', 'four'])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Dallas      4    5      6     7
# NJ          8    9     10    11
# New York   12   13     14    15

# %%
data.drop(['NJ', 'Ohio'])
# Out:
#           one  two  three  four
# Dallas      4    5      6     7
# New York   12   13     14    15

# %%
obj = pd.Series (np.arange(4.), index=['a', 'b', 'c', 'd'])
print("obj ['b']= \n",obj ['b'])
print("obj [1]= \n", obj [1])
print("obj [2:4]= \n",obj [2:4])
print("obj [['b', 'a', 'd']]= \n", obj [['b', 'a', 'd']])
print("obj [b:d]= \n",obj ['b': 'd'])
print("obj [[1, 3]]= \n", obj [[1, 3]])
print("obj [obj < 2]= \n", obj [obj < 2])
# Out:
# obj ['b']=
#  1.0
# obj [1]=
#  1.0
# obj [2:4]=
#  c    2.0
# d    3.0
# dtype: float64
# obj [['b', 'a', 'd']]=
#  b    1.0
# a    0.0
# d    3.0
# dtype: float64
# obj [b:d]=
#  b    1.0
# c    2.0
# d    3.0
# dtype: float64
# obj [[1, 3]]=
#  b    1.0
# d    3.0
# dtype: float64
# obj [obj < 2]=
#  a    0.0
# b    1.0
# dtype: float64
# /tmp/ipython-input-3426489539.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print("obj [1]= \n", obj [1])
# /tmp/ipython-input-3426489539.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print("obj [[1, 3]]= \n", obj [[1, 3]])

# %%
data = pd.DataFrame(np.arange(24).reshape((6, 4)),
index=['Ohio', 'Dallas', 'Boston', 'NJ', 'New York', 'Austin'], columns=['one', 'two', 'three', 'four'])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Dallas      4    5      6     7
# Boston      8    9     10    11
# NJ         12   13     14    15
# New York   16   17     18    19
# Austin     20   21     22    23

# %%
data['two']
# Out:
# Ohio         1
# Dallas       5
# Boston       9
# NJ          13
# New York    17
# Austin      21
# Name: two, dtype: int64

# %%
data[1:5]
# Out:
#           one  two  three  four
# Dallas      4    5      6     7
# Boston      8    9     10    11
# NJ         12   13     14    15
# New York   16   17     18    19

# %%
data.loc['Dallas', ['two', 'three']]
# Out:
# two      5
# three    6
# Name: Dallas, dtype: int64

# %%
data.at['Dallas', 'one']
# Out:
# np.int64(4)

# %%
data.iloc[3]
# Out:
# one      12
# two      13
# three    14
# four     15
# Name: NJ, dtype: int64

# %%
data.iloc[2:5, 0:2]
# Out:
#           one  two
# Boston      8    9
# NJ         12   13
# New York   16   17

# %%
data.iloc[1:4, :]
# Out:
#         one  two  three  four
# Dallas    4    5      6     7
# Boston    8    9     10    11
# NJ       12   13     14    15

# %%
print(data.three  > 5)
data[data.three > 5]
# Out:
# Ohio        False
# Dallas       True
# Boston       True
# NJ           True
# New York     True
# Austin       True
# Name: three, dtype: bool
#           one  two  three  four
# Dallas      4    5      6     7
# Boston      8    9     10    11
# NJ         12   13     14    15
# New York   16   17     18    19
# Austin     20   21     22    23

# %%
data < 5
data[data < 5] = 0
data
# Out:
#           one  two  three  four
# Ohio        0    0      0     0
# Dallas      0    5      6     7
# Boston      8    9     10    11
# NJ         12   13     14    15
# New York   16   17     18    19
# Austin     20   21     22    23

# %%
df1 = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df2 = pd.DataFrame({'A': [7, 8, 9], 'B': [10, 11, 12]})
print(df1)
print(df2)

print("Addition: \n", df1+df2)
print("\nSubtraction: \n", df1 - df2)
print("\nMultiplication: \n", df1*df2)
print("\nDivision: \n", df1 / df2)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
#    A   B
# 0  7  10
# 1  8  11
# 2  9  12
# Addition:
#      A   B
# 0   8  14
# 1  10  16
# 2  12  18
#
# Subtraction:
#     A  B
# 0 -6 -6
# 1 -6 -6
# 2 -6 -6
#
# Multiplication:
#      A   B
# 0   7  40
# 1  16  55
# 2  27  72
#
# Division:
#            A         B
# 0  0.142857  0.400000
# 1  0.250000  0.454545
# 2  0.333333  0.500000

# %%
df3 = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]}, index= [0, 1, 2])
df4= pd.DataFrame({'B': [7, 8, 9], 'C': [10, 11, 12]}, index= [1, 2, 3])
print(df3)
print(df4)
result = df3 + df4
print("Result of df3 = df4 with alignment:\n",result)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
#    B   C
# 1  7  10
# 2  8  11
# 3  9  12
# Result of df3 = df4 with alignment:
#      A     B   C
# 0 NaN   NaN NaN
# 1 NaN  12.0 NaN
# 2 NaN  14.0 NaN
# 3 NaN   NaN NaN

# %%
df3-df4
# Out:
#     A    B   C
# 0 NaN  NaN NaN
# 1 NaN -2.0 NaN
# 2 NaN -2.0 NaN
# 3 NaN  NaN NaN

# %%
result_add = df3.add(df4, fill_value=0)
print("\nResult of df3.add(df4) with fill_value=0:\n", result_add)
# Out:
# Result of df3.add(df4) with fill_value=0:
#       A     B     C
# 0  1.0   4.0   NaN
# 1  2.0  12.0  10.0
# 2  3.0  14.0  11.0
# 3  NaN   9.0  12.0

# %%
obj = pd.Series (range(4), index=['d', 'a', 'b', 'c'])
df_sort_series = obj.sort_index()
print (df_sort_series)

frame = pd.DataFrame(np.arange(8).reshape((2, 4)),
index=['three', 'one'],
columns=['d', 'a', 'b', 'c'])
df_sort_dataframe = frame. sort_index()
print("I \n", df_sort_dataframe)

df_sort_dataframe_axis1 = frame.sort_index(axis=1)
df_sort_dataframe_ascending = frame. sort_index (axis=1, ascending=False)
print("III \n", df_sort_dataframe_ascending)
df_sort_values_by_column = frame.sort_values(by='b')
print("IV \n", df_sort_values_by_column)
# Out:
# a    1
# b    2
# c    3
# d    0
# dtype: int64
# I
#         d  a  b  c
# one    4  5  6  7
# three  0  1  2  3
# III
#         d  c  b  a
# three  0  3  2  1
# one    4  7  6  5
# IV
#         d  a  b  c
# three  0  1  2  3
# one    4  5  6  7

# %%
obj = pd.Series ([7, -5, 7, 3, 2, 0, 4])
df_rank = obj.rank()
print("Rank \n", df_rank)

df_rank_method_first = obj. rank (method='first')
print("rank- Method=first \n", df_rank_method_first)

df_rank_ascending = obj.rank (ascending=False, method='max')
print("rank- Method=max \n", df_rank_ascending)

frame = pd.DataFrame({'b': [4.3, 7, -3, 2], 'a': [0, 1, 0, 1],'c': [-2, 5, 8, -2.5]})
print("Rank over rows \n", frame)
df_rank_dataframe = frame. rank (axis='columns')
print("Rank over columns \n", df_rank_dataframe)
# Out:
# Rank
#  0    6.5
# 1    1.0
# 2    6.5
# 3    4.0
# 4    3.0
# 5    2.0
# 6    5.0
# dtype: float64
# rank- Method=first
#  0    6.0
# 1    1.0
# 2    7.0
# 3    4.0
# 4    3.0
# 5    2.0
# 6    5.0
# dtype: float64
# rank- Method=max
#  0    2.0
# 1    7.0
# 2    2.0
# 3    4.0
# 4    5.0
# 5    6.0
# 6    3.0
# dtype: float64
# Rank over rows
#       b  a    c
# 0  4.3  0 -2.0
# 1  7.0  1  5.0
# 2 -3.0  0  8.0
# 3  2.0  1 -2.5
# Rank over columns
#       b    a    c
# 0  3.0  2.0  1.0
# 1  3.0  1.0  2.0
# 2  1.0  2.0  3.0
# 3  3.0  2.0  1.0
